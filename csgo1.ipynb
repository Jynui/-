# %% [markdown]
# <a href="https://colab.research.google.com/github/Jynui/-/blob/main/csgo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = [22622,35512,18091	]
y = [16458,26413,12492	]
plt.plot(x, y, label='Статистика убийств-смерти')
plt.xlabel('Убийства')
plt.ylabel('Смерти')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# На этом графике мы можем наблюдать статистику убийств и смертей игроков csgo(Zywoo,S1mple,Sh1ro)

# %%
import matplotlib.pyplot as plt
x = [8552,13451,10580	]
y = [8261,14717,3791	]
plt.plot(x, y, label='Статистика убийств с автоматов и снайперок')
plt.xlabel('sniper_kills')
plt.ylabel('rifle_kills')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# На данном графике мы видем статистику проигроков c разных оружий (Zywoo,S1mple,Sh1ro)

# %%
import matplotlib.pyplot as plt
x = [1290	,901	,	550	]
y = [4262	,6057	,	3008]
plt.plot(x, y, label='Статистика убийств с пп и пистолетов')
plt.xlabel('smg_kills')
plt.ylabel('pistol_kills')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# На данном графике мы видем что статистика проигроков убийств с пп и пистолетов падает (ZywOo,S1mple,Sh1ro)

# %%
import matplotlib.pyplot as plt
x = [1,5,10,15,20]
y = [1.32,1.25,1.26,1.26,1.25]
plt.bar(x, y, color='green', label='Rating K/D')
plt.xlabel('S1mple              Sh1ro               Zywoo            deko             saffee')
plt.ylabel('Rating K/D')
plt.title('Rating')
# Out:
# Text(0.5, 1.0, 'Rating')

# %% [markdown]
#   На данном графике мы видем как K/D проигроков растет (s1mple,sh1ro,zywoo,deko,saffee)

# %%
import matplotlib.pyplot as plt
y = [12000,20000,17000,20000,15000]
x = [1,2,3,4,5]
plt.bar(x, y, color='red', label='Среднее количество убийств за раунд')
plt.xlabel('Количесвто проигроков')
plt.ylabel('Количество убийств')
plt.title('Среднее количество убийств за раунд')
# Out:
# Text(0.5, 1.0, 'Среднее количество убийств за раунд')

# %% [markdown]
# На графике мы видем проигроков их среднее количество убийств за раунд (за все сыгранные матчи)не ниже 12500 киллов(s1mple,sh1ro,zywoo,deko,saffee)

# %%
import matplotlib.pyplot as plt
x = [15,20,30,40,50]
y = [21, 24, 21, 21, 27]
plt.bar(x, y, color='yellow', label='Возраст')
plt.xlabel('Количество проигроков')
plt.ylabel('Возраст проигкрока')
plt.title('Возраст ')
# Out:
# Text(0.5, 1.0, 'Возраст ')

# %% [markdown]
# На графике мы можем посмотреть что 50 проигроков чуть старше 25 лет и так же мы можем наблюдать за остальными возрастами проигроков

# %%
import matplotlib.pyplot as plt
vals = [20 , 40, 15, 25]
labels = ["Zywoo(41.2%)", "S1mple(41.3%)", "Sh1ro(27.8%)", "deko(36.7%)"]
plt.pie(vals, labels=labels)
plt.title("Процент попадания в голову ")
plt.show()

# %% [markdown]
# Тут наблюдаем такую же круговую диаграмму отражающимим соотношените процент попадание в голову проигроков (самый высокий процент это у S1mple)

# %%
import matplotlib.pyplot as plt
vals = [30 , 60, 50, 100]
labels = ["saffee	(30.2%)", "B1ad3(41.9%)", "netrick(41.8%)", "HUNDEN(48.7%)"]
plt.pie(vals, labels=labels)
plt.title("Процент попадания в голову ")
plt.show()

# %% [markdown]
# На данной круглой диаграмме мы можем увидеть дргих проигроков и процент попадания в голову

# %%
x = [49, 254, 70, 40]
y = [100, 100, 100, 100]
plt.scatter(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Диаграмму рассеивания показывает другие убийства проигроков которые были сделаны не с оружия так же информация была взята первых лидеров HLTV

# %%
x = [71, 64, 30, 8, 14]
y = [100, 100, 100, 100, 100]
plt.scatter(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# На этой диагрмме показано сколько проигроков сделали эйсов за сезон
# Эйс-устранение всей команды противника одним игроком.
# Так же информация была взята у первых лидеров HLTV

# %%
import pandas as pd
import numpy as np

# %%
CSGO= pd.read_csv("csgo_players.csv")
plt.hist(CSGO["age"], bins= 20, color = "red")
# Out:
# (array([ 1.,  5., 15., 32., 47., 59., 64., 85., 90., 83., 74., 72., 47.,
#         38., 28., 33., 15., 13.,  9.,  1.]),
#  array([17.  , 17.95, 18.9 , 19.85, 20.8 , 21.75, 22.7 , 23.65, 24.6 ,
#         25.55, 26.5 , 27.45, 28.4 , 29.35, 30.3 , 31.25, 32.2 , 33.15,
#         34.1 , 35.05, 36.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Самый продуктивный возраст это 25 лет для проигрока это средний показатель (но в этот возраст много кто заканчивает корьеру проигрока)

# %% [markdown]
# Тут мы импортируем PANDAS и NAMPY для хорошей работой с гистограммами

# %%
cs = pd.read_csv("csgo_players.csv")
plt.hist(cs["rating"], bins= 20, color = "blue")
# Out:
# (array([  1.,   2.,   5.,   6.,  20.,  36.,  62.,  50., 134., 132., 128.,
#          82.,  76.,  45.,  17.,   6.,   6.,   2.,   0.,   1.]),
#  array([0.77  , 0.7975, 0.825 , 0.8525, 0.88  , 0.9075, 0.935 , 0.9625,
#         0.99  , 1.0175, 1.045 , 1.0725, 1.1   , 1.1275, 1.155 , 1.1825,
#         1.21  , 1.2375, 1.265 , 1.2925, 1.32  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Rating на этом графике очень высокий но при этом мало людей кто мог забраться до этого уровня но так же удалось 3 игрокам (ZywOo,S1mple,Sh1ro)

# %%
XD= pd.read_csv("csgo_players.csv")
plt.hist(XD["total_deaths"], bins= 20, color = "blue")
# Out:
# (array([104., 130.,  84.,  81.,  65.,  66.,  53.,  40.,  43.,  22.,  24.,
#          24.,  13.,  13.,  13.,  11.,   8.,   5.,   9.,   3.]),
#  array([ 6166. ,  7784.4,  9402.8, 11021.2, 12639.6, 14258. , 15876.4,
#         17494.8, 19113.2, 20731.6, 22350. , 23968.4, 25586.8, 27205.2,
#         28823.6, 30442. , 32060.4, 33678.8, 35297.2, 36915.6, 38534. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# На этом графике мы видем лучший показатель убийства за сезон
# Но это не самый высокий рейтинг за сезон бывало и лучше
